# %% [markdown]
# Admission campaign analysis

# %%
import pandas as pd

pd.read_html(io="http://pstu.ru/files/file/Abitur/2025%20final/%D0%93%D0%9D%D0%A4_%D0%91_%D0%9D_000007843.html")
# Out:
# [                                                   0   \
#  0                                  Списки поступающих
#  1                                                 NaN
#  2   Дата формирования - 14.08.2025. Время формиров...
#  3                              Форма обучения - Очная
#  4            Подразделение - Горно-нефтяной факультет
#  5                    Уровень подготовки - Специалитет
#  6   УГС/Направление подготовки/специальность - При...
#  7            Основание поступления - Бюджетная основа
#  8              Категория приема - На общих основаниях
#  9   Конкурсная группа - 21.00.00 (О-Б) Нефтегазова...
#  10    Всего мест: 38. Зачислено: 38. К зачислению: 0.
#  11                                                NaN
#  12                                                  №
#  13                                                  1
#  14                                                  2
#  15                                                  3
# ...
